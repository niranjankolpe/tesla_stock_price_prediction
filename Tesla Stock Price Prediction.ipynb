# %% [markdown]
# # Tesla Stock Price Prediction

# %%
import pandas as pd
import datetime
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Tesla.csv')
df
# Out:
#            Date        Open        High         Low       Close    Volume  \
# 0     6/29/2010   19.000000   25.000000   17.540001   23.889999  18766300
# 1     6/30/2010   25.790001   30.420000   23.299999   23.830000  17187100
# 2      7/1/2010   25.000000   25.920000   20.270000   21.959999   8218800
# 3      7/2/2010   23.000000   23.100000   18.709999   19.200001   5139800
# 4      7/6/2010   20.000000   20.000000   15.830000   16.110001   6866900
# ...         ...         ...         ...         ...         ...       ...
# 1687  3/13/2017  244.820007  246.850006  242.779999  246.169998   3010700
# 1688  3/14/2017  246.110001  258.119995  246.020004  258.000000   7575500
# 1689  3/15/2017  257.000000  261.000000  254.270004  255.729996   4816600
# 1690  3/16/2017  262.399994  265.750000  259.059998  262.049988   7100400
# 1691  3/17/2017  264.000000  265.329987  261.200012  261.500000   6475900
#
#        Adj Close
# 0      23.889999
# 1      23.830000
# 2      21.959999
# 3      19.200001
# 4      16.110001
# ...          ...
# 1687  246.169998
# 1688  258.000000
# 1689  255.729996
# 1690  262.049988
# 1691  261.500000
#
# [1692 rows x 7 columns]

# %%
df.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  1692.000000  1692.000000  1692.000000  1692.000000  1.692000e+03
# mean    132.441572   134.769698   129.996223   132.428658  4.270741e+06
# std      94.309923    95.694914    92.855227    94.313187  4.295971e+06
# min      16.139999    16.629999    14.980000    15.800000  1.185000e+05
# 25%      30.000000    30.650000    29.215000    29.884999  1.194350e+06
# 50%     156.334999   162.370002   153.150002   158.160004  3.180700e+06
# 75%     220.557495   224.099999   217.119999   220.022503  5.662100e+06
# max     287.670013   291.420013   280.399994   286.040009  3.716390e+07
#
#          Adj Close
# count  1692.000000
# mean    132.428658
# std      94.313187
# min      15.800000
# 25%      29.884999
# 50%     158.160004
# 75%     220.022503
# max     286.040009

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1692 entries, 0 to 1691
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1692 non-null   object
#  1   Open       1692 non-null   float64
#  2   High       1692 non-null   float64
#  3   Low        1692 non-null   float64
#  4   Close      1692 non-null   float64
#  5   Volume     1692 non-null   int64
#  6   Adj Close  1692 non-null   float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 92.7+ KB

# %%
df[['Date']] = df[['Date']].apply(pd.to_datetime)
df['Date'] = df['Date'].dt.strftime('%Y')
df['Date'] = df['Date'].astype(np.int64)
df
# Out:
#       Date        Open        High         Low       Close    Volume  \
# 0     2010   19.000000   25.000000   17.540001   23.889999  18766300
# 1     2010   25.790001   30.420000   23.299999   23.830000  17187100
# 2     2010   25.000000   25.920000   20.270000   21.959999   8218800
# 3     2010   23.000000   23.100000   18.709999   19.200001   5139800
# 4     2010   20.000000   20.000000   15.830000   16.110001   6866900
# ...    ...         ...         ...         ...         ...       ...
# 1687  2017  244.820007  246.850006  242.779999  246.169998   3010700
# 1688  2017  246.110001  258.119995  246.020004  258.000000   7575500
# 1689  2017  257.000000  261.000000  254.270004  255.729996   4816600
# 1690  2017  262.399994  265.750000  259.059998  262.049988   7100400
# 1691  2017  264.000000  265.329987  261.200012  261.500000   6475900
#
#        Adj Close
# 0      23.889999
# 1      23.830000
# 2      21.959999
# 3      19.200001
# 4      16.110001
# ...          ...
# 1687  246.169998
# 1688  258.000000
# 1689  255.729996
# 1690  262.049988
# 1691  261.500000
#
# [1692 rows x 7 columns]

# %%
sns.regplot(data=df, x='Volume', y='Adj Close')
plt.show()

# %%
df.dtypes
# Out:
# Date           int64
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Volume         int64
# Adj Close    float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Volume       0
# Adj Close    0
# dtype: int64

# %%
df.duplicated().value_counts()
# Out:
# False    1692
# dtype: int64

# %%
x = df.drop(columns = ['Adj Close'])
x
# Out:
#       Date        Open        High         Low       Close    Volume
# 0     2010   19.000000   25.000000   17.540001   23.889999  18766300
# 1     2010   25.790001   30.420000   23.299999   23.830000  17187100
# 2     2010   25.000000   25.920000   20.270000   21.959999   8218800
# 3     2010   23.000000   23.100000   18.709999   19.200001   5139800
# 4     2010   20.000000   20.000000   15.830000   16.110001   6866900
# ...    ...         ...         ...         ...         ...       ...
# 1687  2017  244.820007  246.850006  242.779999  246.169998   3010700
# 1688  2017  246.110001  258.119995  246.020004  258.000000   7575500
# 1689  2017  257.000000  261.000000  254.270004  255.729996   4816600
# 1690  2017  262.399994  265.750000  259.059998  262.049988   7100400
# 1691  2017  264.000000  265.329987  261.200012  261.500000   6475900
#
# [1692 rows x 6 columns]

# %%
y = df['Adj Close']
y
# Out:
# 0        23.889999
# 1        23.830000
# 2        21.959999
# 3        19.200001
# 4        16.110001
#            ...
# 1687    246.169998
# 1688    258.000000
# 1689    255.729996
# 1690    262.049988
# 1691    261.500000
# Name: Adj Close, Length: 1692, dtype: float64

# %% [markdown]
# ## Model Building and Testing

# %%
from sklearn.preprocessing import StandardScaler

std_sclr = StandardScaler()
std_sclr
# Out:
# StandardScaler()

# %%
columns = list(df.columns)
columns.remove('Adj Close')
x = pd.DataFrame(std_sclr.fit_transform(x), columns=columns)
x
# Out:
#           Date      Open      High       Low     Close    Volume
# 0    -1.692373 -1.203215 -1.147419 -1.211450 -1.151173  3.375219
# 1    -1.692373 -1.131197 -1.090764 -1.149400 -1.151809  3.007510
# 2    -1.692373 -1.139576 -1.137802 -1.182041 -1.171642  0.919286
# 3    -1.692373 -1.160789 -1.167280 -1.198846 -1.200915  0.202356
# 4    -1.692373 -1.192608 -1.199684 -1.229871 -1.233688  0.604503
# ...        ...       ...       ...       ...       ...       ...
# 1687  1.854065  1.191939  1.171572  1.214979  1.206353 -0.293394
# 1688  1.854065  1.205621  1.289376  1.249882  1.331823  0.769497
# 1689  1.854065  1.321126  1.319481  1.338756  1.307747  0.127101
# 1690  1.854065  1.378400  1.369133  1.390357  1.374778  0.658872
# 1691  1.854065  1.395371  1.364742  1.413411  1.368944  0.513460
#
# [1692 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=30)

# %%
x_train
# Out:
#           Date      Open      High       Low     Close    Volume
# 1045  0.334163  1.295034  1.277147  1.320874  1.318883 -0.334678
# 652  -0.172471 -1.003071 -1.012889 -1.002569 -1.006717 -0.784534
# 544  -0.679105 -1.086544 -1.086269 -1.080993 -1.078627 -0.651906
# 560  -0.679105 -1.061619 -1.066095 -1.060956 -1.059430 -0.246336
# 1249  0.840797  1.248259  1.240457  1.283062  1.280065 -0.532293
# ...        ...       ...       ...       ...       ...       ...
# 919   0.334163  0.809469  0.873767  0.843754  0.903867  0.933164
# 1164  0.840797  0.648357  0.714150  0.681733  0.747214  2.649511
# 500  -0.679105 -1.041360 -1.050415 -1.057401 -1.063142 -0.553901
# 941   0.334163  0.949369  0.918087  0.876395  0.854124  0.613910
# 421  -0.679105 -1.046133 -1.052088 -1.043397 -1.050202 -0.869686
#
# [1184 rows x 6 columns]

# %%
y_train
# Out:
# 1045    256.779999
# 652      37.509998
# 544      30.730000
# 560      32.540001
# 1249    253.119995
#            ...
# 919     217.649994
# 1164    202.880005
# 500      32.189999
# 941     212.960007
# 421      33.410000
# Name: Adj Close, Length: 1184, dtype: float64

# %%
x_test
# Out:
#           Date      Open      High       Low     Close    Volume
# 1102  0.334163  1.243910  1.228958  1.245142  1.237429  0.372566
# 1240  0.840797  1.227789  1.212025  1.260547  1.236262 -0.581004
# 659  -0.172471 -1.001904 -0.999509 -0.996428 -0.997066 -0.233879
# 424  -0.679105 -1.040406 -1.049161 -1.039950 -1.046384 -0.885682
# 573  -0.679105 -1.086544 -1.094109 -1.091766 -1.092733 -0.635537
# ...        ...       ...       ...       ...       ...       ...
# 307  -1.185739 -1.144031 -1.148151 -1.138304 -1.141309 -0.863422
# 156  -1.185739 -1.148804 -1.155990 -1.154894 -1.158385 -0.380734
# 370  -1.185739 -1.091847 -1.098499 -1.098768 -1.101960 -0.723413
# 1314  0.840797  1.394947  1.366519  1.407917  1.374990 -0.159485
# 1621  1.347431  0.531049  0.565718  0.565712  0.576668 -0.046229
#
# [508 rows x 6 columns]

# %%
y_test
# Out:
# 1102    249.100006
# 1240    248.990005
# 659      38.419998
# 424      33.770000
# 573      29.400000
#            ...
# 307      24.820000
# 156      23.209999
# 370      28.530001
# 1314    262.070007
# 1621    186.800003
# Name: Adj Close, Length: 508, dtype: float64

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %% [markdown]
# ### 1) Support Vector Regression

# %%
from sklearn.svm import SVR

svr = SVR()
svr.fit(x, y)

y_pred_svr          = svr.predict(x_test)

y_pred_svr_r2_score = r2_score(y_test, y_pred_svr)
y_pred_svr_mae      = mean_absolute_error(y_test, y_pred_svr)
y_pred_svr_mse      = mean_squared_error(y_test, y_pred_svr)
y_pred_svr_rmse     = np.sqrt(mean_squared_error(y_test, y_pred_svr))

# %% [markdown]
# ### 2) Linear Regression

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(x_train, y_train)

y_pred_lin_reg = lin_reg.predict(x_test)

y_pred_lin_reg_r2_score = r2_score(y_test, y_pred_lin_reg)
y_pred_lin_reg_mae      = mean_absolute_error(y_test, y_pred_lin_reg)
y_pred_lin_reg_mse      = mean_squared_error(y_test, y_pred_lin_reg)
y_pred_lin_reg_rmse     = np.sqrt(mean_squared_error(y_test, y_pred_lin_reg))

# %% [markdown]
# ### 3)  Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor

randf_clf = RandomForestRegressor(n_estimators=500, random_state=30)
randf_clf.fit(x_train, y_train)

y_pred_randf_clf = randf_clf.predict(x_test)

y_pred_randf_clf_r2_score = r2_score(y_test, y_pred_randf_clf)
y_pred_randf_clf_mae      = mean_absolute_error(y_test, y_pred_randf_clf)
y_pred_randf_clf_mse      = mean_squared_error(y_test, y_pred_randf_clf)
y_pred_randf_clf_rmse     = np.sqrt(mean_squared_error(y_test, y_pred_randf_clf))

# %% [markdown]
# ### 4) Gradient Boosting Regression

# %%
from sklearn.ensemble import GradientBoostingRegressor

gbr = GradientBoostingRegressor(random_state=30, n_estimators=1000, max_depth=10)
gbr.fit(x_train, y_train)

y_pred_gbr = gbr.predict(x_test)

y_pred_gbr_r2_score = r2_score(y_test, y_pred_gbr)
y_pred_gbr_mae      = mean_absolute_error(y_test, y_pred_gbr)
y_pred_gbr_mse      = mean_squared_error(y_test, y_pred_gbr)
y_pred_gbr_rmse     = np.sqrt(mean_squared_error(y_test, y_pred_gbr))

# %%
model_result = {'Original Result':y_test, 'SVR':y_pred_svr, 'Lin.Reg.':y_pred_lin_reg, 'Rand.Fore.Reg.':y_pred_randf_clf,
                'Gra.Boost.Reg.':y_pred_gbr}
model_result = pd.DataFrame(model_result)
model_result
# Out:
#       Original Result         SVR    Lin.Reg.  Rand.Fore.Reg.  Gra.Boost.Reg.
# 1102       249.100006  244.724107  249.100006      249.121960      249.156636
# 1240       248.990005  240.395545  248.990005      248.953599      248.933424
# 659         38.419998   43.746768   38.419998       38.354280       38.363959
# 424         33.770000   32.911544   33.770000       33.782140       33.779999
# 573         29.400000   30.081071   29.400000       29.403220       29.391293
# ...               ...         ...         ...             ...             ...
# 307         24.820000   26.630852   24.820000       24.849740       24.917519
# 156         23.209999   26.078118   23.209999       23.214540       23.182954
# 370         28.530001   26.767982   28.530001       28.523280       28.530001
# 1314       262.070007  252.869259  262.070007      262.211501      262.059956
# 1621       186.800003  185.124223  186.800003      186.805400      187.289228
#
# [508 rows x 5 columns]

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(model_result)
plt.xlabel("Model Name")
plt.ylabel("Predicted Result")
plt.show()

# %%
model_evaluation = {'Model Name':["Support Vector Regression", "Linear Regression", "Random Forest Regression",
                                  "Gradient Boosting Regression"],
                    'R2 Score':[y_pred_svr_r2_score, y_pred_lin_reg_r2_score, y_pred_randf_clf_r2_score, y_pred_gbr_r2_score],
                    'MAE':[y_pred_svr_mae, y_pred_lin_reg_mae, y_pred_randf_clf_mae, y_pred_gbr_mae],
                    'MSE':[y_pred_svr_mse, y_pred_lin_reg_mse, y_pred_randf_clf_mse, y_pred_gbr_mse],
                    'RMSE':[y_pred_svr_rmse, y_pred_lin_reg_rmse, y_pred_randf_clf_rmse, y_pred_gbr_rmse]}
model_evaluation = pd.DataFrame(model_evaluation)
model_evaluation
# Out:
#                      Model Name  R2 Score           MAE           MSE  \
# 0     Support Vector Regression  0.987780  5.428004e+00  1.109279e+02
# 1             Linear Regression  1.000000  2.933786e-14  1.298825e-27
# 2      Random Forest Regression  0.999981  1.767786e-01  1.754525e-01
# 3  Gradient Boosting Regression  0.999983  1.833665e-01  1.575333e-01
#
#            RMSE
# 0  1.053223e+01
# 1  3.603922e-14
# 2  4.188705e-01
# 3  3.969047e-01

# %% [markdown]
# ### Model Selected: Linear Regression

# %%
sns.regplot(data=model_result, x='Original Result', y='Lin.Reg.', color='blue', line_kws={"color": "red"})
plt.xlabel("Actual Value")
plt.ylabel("Predicted Value")
plt.title("Linear Regression")
plt.show()

# %%
import pandas as pd
import datetime
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

from flask import Flask
import joblib
from flask import render_template
from flask import request

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Tesla.csv')
df
# Out:
#            Date        Open        High         Low       Close    Volume  \
# 0     6/29/2010   19.000000   25.000000   17.540001   23.889999  18766300
# 1     6/30/2010   25.790001   30.420000   23.299999   23.830000  17187100
# 2      7/1/2010   25.000000   25.920000   20.270000   21.959999   8218800
# 3      7/2/2010   23.000000   23.100000   18.709999   19.200001   5139800
# 4      7/6/2010   20.000000   20.000000   15.830000   16.110001   6866900
# ...         ...         ...         ...         ...         ...       ...
# 1687  3/13/2017  244.820007  246.850006  242.779999  246.169998   3010700
# 1688  3/14/2017  246.110001  258.119995  246.020004  258.000000   7575500
# 1689  3/15/2017  257.000000  261.000000  254.270004  255.729996   4816600
# 1690  3/16/2017  262.399994  265.750000  259.059998  262.049988   7100400
# 1691  3/17/2017  264.000000  265.329987  261.200012  261.500000   6475900
#
#        Adj Close
# 0      23.889999
# 1      23.830000
# 2      21.959999
# 3      19.200001
# 4      16.110001
# ...          ...
# 1687  246.169998
# 1688  258.000000
# 1689  255.729996
# 1690  262.049988
# 1691  261.500000
#
# [1692 rows x 7 columns]

# %%
df['Date'] = df['Date'].apply(pd.to_datetime)
df['Date'] = df['Date'].dt.strftime('%Y')
df['Date'] = df['Date'].astype(np.int64)

# %%
df
# Out:
#       Date        Open        High         Low       Close    Volume  \
# 0     2010   19.000000   25.000000   17.540001   23.889999  18766300
# 1     2010   25.790001   30.420000   23.299999   23.830000  17187100
# 2     2010   25.000000   25.920000   20.270000   21.959999   8218800
# 3     2010   23.000000   23.100000   18.709999   19.200001   5139800
# 4     2010   20.000000   20.000000   15.830000   16.110001   6866900
# ...    ...         ...         ...         ...         ...       ...
# 1687  2017  244.820007  246.850006  242.779999  246.169998   3010700
# 1688  2017  246.110001  258.119995  246.020004  258.000000   7575500
# 1689  2017  257.000000  261.000000  254.270004  255.729996   4816600
# 1690  2017  262.399994  265.750000  259.059998  262.049988   7100400
# 1691  2017  264.000000  265.329987  261.200012  261.500000   6475900
#
#        Adj Close
# 0      23.889999
# 1      23.830000
# 2      21.959999
# 3      19.200001
# 4      16.110001
# ...          ...
# 1687  246.169998
# 1688  258.000000
# 1689  255.729996
# 1690  262.049988
# 1691  261.500000
#
# [1692 rows x 7 columns]

# %%
x = df.drop(columns = ['Adj Close'])
x
# Out:
#       Date        Open        High         Low       Close    Volume
# 0     2010   19.000000   25.000000   17.540001   23.889999  18766300
# 1     2010   25.790001   30.420000   23.299999   23.830000  17187100
# 2     2010   25.000000   25.920000   20.270000   21.959999   8218800
# 3     2010   23.000000   23.100000   18.709999   19.200001   5139800
# 4     2010   20.000000   20.000000   15.830000   16.110001   6866900
# ...    ...         ...         ...         ...         ...       ...
# 1687  2017  244.820007  246.850006  242.779999  246.169998   3010700
# 1688  2017  246.110001  258.119995  246.020004  258.000000   7575500
# 1689  2017  257.000000  261.000000  254.270004  255.729996   4816600
# 1690  2017  262.399994  265.750000  259.059998  262.049988   7100400
# 1691  2017  264.000000  265.329987  261.200012  261.500000   6475900
#
# [1692 rows x 6 columns]

# %%
y = df['Adj Close']
y
# Out:
# 0        23.889999
# 1        23.830000
# 2        21.959999
# 3        19.200001
# 4        16.110001
#            ...
# 1687    246.169998
# 1688    258.000000
# 1689    255.729996
# 1690    262.049988
# 1691    261.500000
# Name: Adj Close, Length: 1692, dtype: float64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
x_train
# Out:
#       Date        Open        High         Low       Close    Volume
# 922   2014  261.250000  261.899994  248.330002  252.539993  17945800
# 755   2013  108.570000  109.440002  106.709999  107.360001   5748600
# 86    2010   21.139999   21.850000   21.049999   21.840000    280600
# 1198  2015  190.229996  193.229996  190.000000  191.000000   5010400
# 1189  2015  197.449997  198.990005  195.619995  198.080002   4269500
# ...    ...         ...         ...         ...         ...       ...
# 1130  2014  223.809998  224.320007  219.520004  220.970001   4505700
# 1294  2015  260.329987  260.649994  255.020004  255.250000   3596200
# 860   2013  119.379997  122.720001  116.099998  120.500000  13885500
# 1459  2016  251.309998  254.600006  249.119995  254.509995   3752400
# 1126  2014  193.059998  206.649994  192.649994  205.820007   7367800
#
# [1184 rows x 6 columns]

# %%
y_train
# Out:
# 922     252.539993
# 755     107.360001
# 86       21.840000
# 1198    191.000000
# 1189    198.080002
#            ...
# 1130    220.970001
# 1294    255.250000
# 860     120.500000
# 1459    254.509995
# 1126    205.820007
# Name: Adj Close, Length: 1184, dtype: float64

# %%
x_test
# Out:
#       Date        Open        High         Low       Close   Volume
# 989   2014  204.350006  206.259995  200.399994  203.990005  3427400
# 1637  2016  221.529999  223.800003  217.199997  219.740005  3782500
# 1217  2015  230.389999  232.889999  225.169998  226.050003  3911900
# 1175  2015  202.699997  203.339996  195.830002  197.330002  7922100
# 1373  2015  224.710007  228.490005  223.639999  227.070007  2067000
# ...    ...         ...         ...         ...         ...      ...
# 839   2013  170.179993  170.500000  162.199997  162.860001  7841700
# 1053  2014  284.010010  291.420013  280.399994  286.040009  8341700
# 643   2013   34.160000   34.849998   33.919998   34.380001  1436700
# 177   2011   23.850000   24.250000   23.530001   24.070000   930800
# 287   2011   26.389999   26.650000   25.510000   25.830000   643700
#
# [508 rows x 6 columns]

# %%
y_test
# Out:
# 989     203.990005
# 1637    219.740005
# 1217    226.050003
# 1175    197.330002
# 1373    227.070007
#            ...
# 839     162.860001
# 1053    286.040009
# 643      34.380001
# 177      24.070000
# 287      25.830000
# Name: Adj Close, Length: 508, dtype: float64

# %%
lin_reg = LinearRegression()
lin_reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred
#        212.960007,  29.16    , 207.520004, 251.550003,  34.419998,
#        134.279999,  31.76    ,  33.07    , 181.410004, 221.800003,
#        225.789993, 121.699997, 204.039993, 246.169998,  23.870001,
#        225.119995, 208.449997, 169.660004,  29.6     , 280.019989,
#        181.470001,  28.52    , 200.710007, 218.789993,  27.24    ,
#        172.600006, 239.059998, 143.669998,  20.719999, 200.100006,
#         30.25    , 224.839996, 223.300003,  28.73    ,  30.309999,
#        202.600006, 204.699997, 177.210007,  27.940001, 166.580002,
#        231.630005, 193.369995, 147.940002, 247.729996,  26.01    ,
#         97.730003, 216.889999,  98.18    , 210.190002, 229.589996,
#         33.439999, 199.970001,  31.610001, 211.      , 183.389999,
#         34.380001, 249.990005, 203.600006,  47.830002,  32.540001,
#         33.639999, 193.149994,  33.689999, 200.309998, 247.139999,
#         36.650002, 222.229996, 253.740005, 219.610001,  27.940001,
#         29.129999, 120.25    , 201.      ,  32.959999,  26.959999,
#        248.839996, 197.809998, 236.610001, 162.860001, 286.040009,
#         34.380001,  24.07    ,  25.83    ])

# %%
print("Linear Regression")
print("R2 Score:",                r2_score(y_test, y_pred_lin_reg))
print("Mean Absolute Error:",     mean_absolute_error(y_test, y_pred_lin_reg))
print("Mean Squared Error:",      mean_squared_error(y_test, y_pred_lin_reg))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, y_pred_lin_reg)))
# Out:
# Linear Regression
# R2 Score: 1.0
# Mean Absolute Error: 2.5617303554028022e-14
# Mean Squared Error: 1.0931003315023123e-27
# Root Mean Squared Error: 3.306206786488577e-14

# %%
sns.regplot(x=y_test, y=y_pred_lin_reg, color='blue', line_kws={"color": "red"})
plt.xlabel("Actual Value")
plt.ylabel("Predicted Value")
plt.title("Linear Regression")
plt.show()

# %%
import pickle

with open("linear_regression_model", "wb") as file:
    pickle.dump(lin_reg, file)

# %%
app = Flask(__name__)
model = joblib.load('linear_regression_model')

# %%
@app.route("/")
def home(name = None):
    return render_template("index.html", name = name)

# %%
@app.route("/templates", methods = ["GET", "POST"])
def result():
    if (request.method == "POST"):
        Date = float(request.form.get('Date'))
        Open = float(request.form.get('Open'))
        High = float(request.form.get('High'))
        Low = float(request.form.get('Low'))
        Close = float(request.form.get('Close'))
        Volume = float(request.form.get('Volume'))
        
        inputs = [Date, Open, High, Low, Close, Volume]
        predict_value = model.predict([inputs])
        
        print("The inputs are:", inputs)
        print("The predicted value is:", predict_value[0])
        return render_template("result.html", prediction=predict_value[0])
    else:
        return render_template("result.html", prediction=-1)

# %%
if __name__== "__main__":
    app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [14/Aug/2023 20:46:01] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 20:46:05] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Aug/2023 20:46:05] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [14/Aug/2023 20:46:15] "POST /templates HTTP/1.1" 200 -
# The inputs are: [2017.0, 257.0, 261.0, 254.270004, 255.729996, 4816600.0]
# The predicted value is: 255.72999600000003
# 127.0.0.1 - - [14/Aug/2023 20:46:18] "GET / HTTP/1.1" 200 -
